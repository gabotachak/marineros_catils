# %%
def repartir(catils):
    # Retorna la división, el residuo y lo que queda
    return [int(catils / 3), catils % 3, catils - int(catils / 3) - 1]


def situacion(catils):
    registro = []
    # Repartición de los 3 marineros y el almojarife, siempre debe sobrar 1
    sobras_esperadas = [1]*4
    for sobra_esperada in sobras_esperadas:
        reparto, sobrante, restante = repartir(catils)
        if sobrante == sobra_esperada:
            registro.append([catils, 3, reparto, sobrante, restante])
        else:
            # En caso de que no sobre lo esperado, se retorna un array vacío simbolizando que el registro no es válido,
            # ya que no es como en la situación inicial y no van a ser anexados al resultado.
            return []
        catils = restante

    # No le queda nada al almojarife
    registro[-1][-1] = 0
    return registro


if __name__ == '__main__':
    resultados = {}
    n = 100001
    while len(resultados) < 10:
        intento = situacion(n)
        if intento:
            resultados[n] = intento
        n += 1

    for n, resultado in resultados.items():
        r = []
        print(f"Monedas totales: {n}")
        padding = "{:<20} {:<15} {:<10} {:<10} {:<20}"
        print(padding.format("Monedas en la caja:", "Dividas entre:", "Da:", "Residuo:", "Monedas restantes:"))

        for monedas, divisor, da, residuo, restantes in resultado:
            r.append(da)
            print(padding.format(monedas, divisor, da, residuo, restantes))
        print()

        print(f"Marinero # 1 {r[0]}+{r[3]} = {r[0]+r[3]}")
        print(f"Marinero # 2 {r[1]}+{r[3]} = {r[1]+r[3]}")
        print(f"Marinero # 3 {r[2]}+{r[3]} = {r[2]+r[3]}")
        print(f"Almojarife = 1")
        print(f"Tiradas al mar = 3")
        print(f"Total = {n}")
        print()
# Out:
# Monedas totales: 100033
# Monedas en la caja:  Dividas entre:  Da:        Residuo:   Monedas restantes:
# 100033               3               33344      1          66688
# 66688                3               22229      1          44458
# 44458                3               14819      1          29638
# 29638                3               9879       1          0
#
# Marinero # 1 33344+9879 = 43223
# Marinero # 2 22229+9879 = 32108
# Marinero # 3 14819+9879 = 24698
# Almojarife = 1
# Tiradas al mar = 3
# Total = 100033
#
# Monedas totales: 100114
# Monedas en la caja:  Dividas entre:  Da:        Residuo:   Monedas restantes:
# 100114               3               33371      1          66742
# 66742                3               22247      1          44494
# 44494                3               14831      1          29662
# 29662                3               9887       1          0
#
# Marinero # 1 33371+9887 = 43258
# Marinero # 2 22247+9887 = 32134
# Marinero # 3 14831+9887 = 24718
# Almojarife = 1
# Tiradas al mar = 3
# Total = 100114
#
# Monedas totales: 100195
# Monedas en la caja:  Dividas entre:  Da:        Residuo:   Monedas restantes:
# 100195               3               33398      1          66796
# 66796                3               22265      1          44530
# 44530                3               14843      1          29686
# 29686                3               9895       1          0
#
# Marinero # 1 33398+9895 = 43293
# Marinero # 2 22265+9895 = 32160
# Marinero # 3 14843+9895 = 24738
# Almojarife = 1
# Tiradas al mar = 3
# Total = 100195
#
# Monedas totales: 100276
# Monedas en la caja:  Dividas entre:  Da:        Residuo:   Monedas restantes:
# 100276               3               33425      1          66850
# 66850                3               22283      1          44566
# 44566                3               14855      1          29710
# 29710                3               9903       1          0
#
# Marinero # 1 33425+9903 = 43328
# Marinero # 2 22283+9903 = 32186
# Marinero # 3 14855+9903 = 24758
# Almojarife = 1
# Tiradas al mar = 3
# Total = 100276
#
# Monedas totales: 100357
# Monedas en la caja:  Dividas entre:  Da:        Residuo:   Monedas restantes:
# 100357               3               33452      1          66904
# 66904                3               22301      1          44602
# 44602                3               14867      1          29734
# 29734                3               9911       1          0
#
# Marinero # 1 33452+9911 = 43363
# Marinero # 2 22301+9911 = 32212
# Marinero # 3 14867+9911 = 24778
# Almojarife = 1
# Tiradas al mar = 3
# Total = 100357
#
# Monedas totales: 100438
# Monedas en la caja:  Dividas entre:  Da:        Residuo:   Monedas restantes:
# 100438               3               33479      1          66958
# 66958                3               22319      1          44638
# 44638                3               14879      1          29758
# 29758                3               9919       1          0
#
# Marinero # 1 33479+9919 = 43398
# Marinero # 2 22319+9919 = 32238
# Marinero # 3 14879+9919 = 24798
# Almojarife = 1
# Tiradas al mar = 3
# Total = 100438
#
# Monedas totales: 100519
# Monedas en la caja:  Dividas entre:  Da:        Residuo:   Monedas restantes:
# 100519               3               33506      1          67012
# 67012                3               22337      1          44674
# 44674                3               14891      1          29782
# 29782                3               9927       1          0
#
# Marinero # 1 33506+9927 = 43433
# Marinero # 2 22337+9927 = 32264
# Marinero # 3 14891+9927 = 24818
# Almojarife = 1
# Tiradas al mar = 3
# Total = 100519
#
# Monedas totales: 100600
# Monedas en la caja:  Dividas entre:  Da:        Residuo:   Monedas restantes:
# 100600               3               33533      1          67066
# 67066                3               22355      1          44710
# 44710                3               14903      1          29806
# 29806                3               9935       1          0
#
# Marinero # 1 33533+9935 = 43468
# Marinero # 2 22355+9935 = 32290
# Marinero # 3 14903+9935 = 24838
# Almojarife = 1
# Tiradas al mar = 3
# Total = 100600
#
# Monedas totales: 100681
# Monedas en la caja:  Dividas entre:  Da:        Residuo:   Monedas restantes:
# 100681               3               33560      1          67120
# 67120                3               22373      1          44746
# 44746                3               14915      1          29830
# 29830                3               9943       1          0
#
# Marinero # 1 33560+9943 = 43503
# Marinero # 2 22373+9943 = 32316
# Marinero # 3 14915+9943 = 24858
# Almojarife = 1
# Tiradas al mar = 3
# Total = 100681
#
# Monedas totales: 100762
# Monedas en la caja:  Dividas entre:  Da:        Residuo:   Monedas restantes:
# 100762               3               33587      1          67174
# 67174                3               22391      1          44782
# 44782                3               14927      1          29854
# 29854                3               9951       1          0
#
# Marinero # 1 33587+9951 = 43538
# Marinero # 2 22391+9951 = 32342
# Marinero # 3 14927+9951 = 24878
# Almojarife = 1
# Tiradas al mar = 3
# Total = 100762
